# %%
import src.enzope as ezp

# %%
gtg = ezp.GTG(n_nodes=100, theta=100, plotable=True)
gtg.plot_snapshot()

# %%
dir(ezp)
# Out:
# ['BaseGraph',
#  'BaseModel',
#  'CPUModel',
#  'GPUEnsemble',
#  'GPUModel',
#  'GTG',
#  'NumbaDeprecationWarning',
#  'NumbaPendingDeprecationWarning',
#  'NumbaPerformanceWarning',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'combinations',
#  'cp',
#  'create_xoroshiro128p_states',
#  'cuda',
#  'display',
#  'double_lock',
#  'double_unlock',
#  'geographical_threshold_graph_custom',
#  'gini',
#  'gini_cupy',
#  'gpu_measures',
#  'graphs',
#  'k_ys',
#  'k_ys_mcs',
#  'k_ys_mcs_graph',
#  'kernels',
#  'liquidity',
#  'math',
#  'measures',
#  'metrics',
#  'models',
#  'np',
#  'num_actives',
#  'num_frozen',
#  'nx',
#  'os',
#  'plt',
#  'py_random_state',
#  'time',
#  'trades',
#  'warnings',
#  'xoroshiro128p_uniform_float32',
#  'yard_sale']
