# %%
import numpy as np
import enzope
import pickle

# %%
mod = enzope.CPUModel(n_agents=100, f=.1, measure_every=1)
mod.MCS(50)

# %%
# Save model as a file
with open('model.pkl', 'wb') as f:
    pickle.dump(mod, f)

# %%
with open('model.pkl', 'rb') as f:
    mod2 = pickle.load(f)

# %%
mod2.__dict__
# Out:
# {'n_agents': 100,
#  'w_min': 3e-17,
#  'r': array([0.15534888, 0.46904022, 0.40629014, 0.6291813 , 0.41996205,
#         0.6200586 , 0.75665987, 0.7944665 , 0.54501486, 0.8956739 ,
#         0.5995243 , 0.00407276, 0.7937939 , 0.9351317 , 0.48839644,
#         0.79775643, 0.05660278, 0.52510756, 0.5170218 , 0.55006194,
#         0.31512463, 0.8737005 , 0.4406579 , 0.37336847, 0.17050786,
#         0.8912446 , 0.3516561 , 0.45959714, 0.7148645 , 0.01122569,
#         0.5066652 , 0.4362226 , 0.19571996, 0.01934346, 0.12913199,
#         0.5289819 , 0.2632083 , 0.8422617 , 0.16613978, 0.40440422,
#         0.77564067, 0.9491681 , 0.78389645, 0.05189186, 0.56242174,
#         0.19586876, 0.9251834 , 0.8913281 , 0.59962547, 0.38515225,
#         0.42976326, 0.73992914, 0.28939843, 0.42690995, 0.8604077 ,
#         0.9007958 , 0.72446346, 0.16508108, 0.6710485 , 0.46732068,
#         0.80822057, 0.72768044, 0.55680174, 0.91928154, 0.9445437 ,
# ...
