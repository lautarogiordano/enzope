# %%
import numpy as np
import enzope
from matplotlib import pyplot as plt

# %%
model = enzope.CPUModel(n_agents=100, f=.05, measure_every=1)
model.MCS(200)
model.save()
model.save("prueba")

# %%
mod = enzope.CPUModel(n_agents=50)
mod.n_agents
# Out:
# 50

# %%
mod.load("model_agents=100_f=0.05_mcs=200_mean_field")

# %%
plt.plot(mod.gini)
