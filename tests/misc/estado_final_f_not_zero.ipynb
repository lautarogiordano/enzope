# %%
import numpy as np
import matplotlib.pyplot as plt
import enzope

# %%
f = .05
n = 80
mcs = int(10e6)
model = enzope.CPUModel(n_agents=n, f=f, measure_every=10)
model.MCS(mcs)

# %%
print(model.n_active[-1])
plt.plot(model.n_active)
# Out:
# 0.25
