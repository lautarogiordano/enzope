# %%
import enzope
import numpy as np
import matplotlib.pyplot as plt

# %%
model = enzope.CPUModel(n_agents=100, f=.3, measure_every=1)
model.run(5000)

# %%
plt.plot(np.sum(model.deciles[:, 8:], axis=1), label='Bottom 50%')
